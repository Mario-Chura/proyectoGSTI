# %%
# === Cargar librerías ===
import ee
import geemap
import sys
import os
sys.path.append(os.path.abspath("../"))
from dotenv import load_dotenv

# === Inicializar entorno ===
load_dotenv()
ee.Initialize(project=os.getenv('EE_PROJECT_ID'))

# === Importar zona de estudio ===
from scripts.zona_estudio import get_zona
zona = get_zona()

# === Crear y mostrar mapa ===
Map = geemap.Map(center=[-16.44, -71.61], zoom=13)
Map.addLayer(zona, {}, 'Zona de Estudio - Tiabaya')
Map
# Out:
# Map(center=[-16.44, -71.61], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchData…
